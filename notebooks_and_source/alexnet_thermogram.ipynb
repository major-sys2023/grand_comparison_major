# %%
from tensorflow import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D
from keras.activations import leaky_relu 
from keras.preprocessing.image import ImageDataGenerator
from keras import Sequential
import matplotlib.pyplot as plt

# %%
np.random.seed(888)

#Instantiate an empty model
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(227, 227,1), kernel_size=(11,11), strides=(4,4), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# Passing it to a Fully Connected layer
model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(4096)) #input_shape=(225*225,)))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))

# 2nd Fully Connected Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# 3rd Fully Connected Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# Output Layer
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 57, 57, 96)        11712
#
#  activation (Activation)     (None, 57, 57, 96)        0
#
#  max_pooling2d (MaxPooling2D  (None, 29, 29, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 256)       614656
#
#  activation_1 (Activation)   (None, 29, 29, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 384)       885120
#
#  activation_2 (Activation)   (None, 15, 15, 384)       0
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 384)       1327488
#
#  activation_3 (Activation)   (None, 15, 15, 384)       0
#
#  conv2d_4 (Conv2D)           (None, 15, 15, 256)       884992
#
#  activation_4 (Activation)   (None, 15, 15, 256)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 4096)              67112960
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 1000)              4097000
#
#  activation_7 (Activation)   (None, 1000)              0
#
#  dropout_2 (Dropout)         (None, 1000)              0
#
#  dense_3 (Dense)             (None, 1)                 1001
#
#  activation_8 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 91,716,241
# Trainable params: 91,716,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_dir="/notebooks/thermograms/Desenvolvimento da Metodologia"
validation_dir=train_dir

# %%
image_shape=(227,227)
# All images will be rescaled by 1./255.
train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

batch_size_curr=64
train_data = keras.preprocessing.image_dataset_from_directory(\
      train_dir,color_mode="grayscale",image_size=image_shape,\
      subset='training',seed=12, validation_split=0.3,batch_size=batch_size_curr)
validation_data = keras.preprocessing.image_dataset_from_directory(\
      validation_dir,color_mode="grayscale",image_size=image_shape,\
      subset='validation',seed=12, validation_split=0.3,batch_size=batch_size_curr)
# Out:
# Found 1282 files belonging to 2 classes.
# Using 898 files for training.
# Found 1282 files belonging to 2 classes.
# Using 384 files for validation.

# %%
model.compile(loss="BinaryCrossentropy", optimizer='Adam', metrics=["BinaryAccuracy"])

# %%
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

# %%
history = model.fit(train_data,
            epochs=100,
            validation_data=validation_data,callbacks=[callback])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 9s 136ms/step - loss: 59.9974 - binary_accuracy: 0.5390 - val_loss: 0.6368 - val_binary_accuracy: 0.7422
# Epoch 2/100
# 15/15 [==============================] - 2s 108ms/step - loss: 0.5397 - binary_accuracy: 0.7728 - val_loss: 1.0236 - val_binary_accuracy: 0.6719
# Epoch 3/100
# 15/15 [==============================] - 2s 91ms/step - loss: 0.5159 - binary_accuracy: 0.7739 - val_loss: 0.4515 - val_binary_accuracy: 0.7760
# Epoch 4/100
# 15/15 [==============================] - 2s 92ms/step - loss: 0.4296 - binary_accuracy: 0.8151 - val_loss: 0.3879 - val_binary_accuracy: 0.7917
# Epoch 5/100
# 15/15 [==============================] - 2s 90ms/step - loss: 0.3740 - binary_accuracy: 0.8229 - val_loss: 0.3564 - val_binary_accuracy: 0.8073
# Epoch 6/100
# 15/15 [==============================] - 2s 88ms/step - loss: 0.3896 - binary_accuracy: 0.8051 - val_loss: 0.3824 - val_binary_accuracy: 0.8099
# Epoch 7/100
# 15/15 [==============================] - 2s 87ms/step - loss: 0.3381 - binary_accuracy: 0.8608 - val_loss: 0.2787 - val_binary_accuracy: 0.8698
# Epoch 8/100
# 15/15 [==============================] - 2s 86ms/step - loss: 0.2786 - binary_accuracy: 0.8708 - val_loss: 0.2863 - val_binary_accuracy: 0.8620
# Epoch 9/100
# 15/15 [==============================] - 2s 90ms/step - loss: 0.1834 - binary_accuracy: 0.9209 - val_loss: 0.4727 - val_binary_accuracy: 0.8411
# Epoch 10/100
# 15/15 [==============================] - 2s 93ms/step - loss: 0.2166 - binary_accuracy: 0.9143 - val_loss: 0.2548 - val_binary_accuracy: 0.9219
# Epoch 11/100
# 15/15 [==============================] - 2s 91ms/step - loss: 0.1628 - binary_accuracy: 0.9354 - val_loss: 0.2187 - val_binary_accuracy: 0.9167
# Epoch 12/100
# 15/15 [==============================] - 2s 89ms/step - loss: 0.1071 - binary_accuracy: 0.9566 - val_loss: 0.2052 - val_binary_accuracy: 0.9036
# Epoch 13/100
# 15/15 [==============================] - 2s 89ms/step - loss: 0.0950 - binary_accuracy: 0.9599 - val_loss: 0.2001 - val_binary_accuracy: 0.9375
# Epoch 14/100
# 15/15 [==============================] - 2s 92ms/step - loss: 0.0750 - binary_accuracy: 0.9644 - val_loss: 0.1763 - val_binary_accuracy: 0.9349
# Epoch 15/100
# 15/15 [==============================] - 2s 90ms/step - loss: 0.0883 - binary_accuracy: 0.9655 - val_loss: 0.1960 - val_binary_accuracy: 0.9245
# Epoch 16/100
# 15/15 [==============================] - 2s 86ms/step - loss: 0.0677 - binary_accuracy: 0.9699 - val_loss: 0.1972 - val_binary_accuracy: 0.9375
# Epoch 17/100
# 15/15 [==============================] - 2s 89ms/step - loss: 0.0464 - binary_accuracy: 0.9777 - val_loss: 0.1855 - val_binary_accuracy: 0.9557
# Epoch 18/100
# 15/15 [==============================] - 2s 93ms/step - loss: 0.0402 - binary_accuracy: 0.9822 - val_loss: 0.2249 - val_binary_accuracy: 0.9323
# Epoch 19/100
# 15/15 [==============================] - 2s 92ms/step - loss: 0.0449 - binary_accuracy: 0.9811 - val_loss: 0.1894 - val_binary_accuracy: 0.9323
# Epoch 20/100
# 15/15 [==============================] - 2s 89ms/step - loss: 0.0707 - binary_accuracy: 0.9722 - val_loss: 0.2495 - val_binary_accuracy: 0.9245
# Epoch 21/100
# 15/15 [==============================] - 2s 90ms/step - loss: 0.0573 - binary_accuracy: 0.9744 - val_loss: 0.2588 - val_binary_accuracy: 0.9219
# Epoch 22/100
# 15/15 [==============================] - 2s 108ms/step - loss: 0.1653 - binary_accuracy: 0.9388 - val_loss: 0.4616 - val_binary_accuracy: 0.8255
# Epoch 23/100
# 15/15 [==============================] - 2s 93ms/step - loss: 0.1993 - binary_accuracy: 0.9243 - val_loss: 0.2257 - val_binary_accuracy: 0.9036
# Epoch 24/100
# 15/15 [==============================] - 2s 91ms/step - loss: 0.0753 - binary_accuracy: 0.9744 - val_loss: 0.3549 - val_binary_accuracy: 0.9089

# %%
epochs_run=len(history.epoch)

# %%
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs_run)
plt.style.use('ggplot')
plt.figure(figsize=(18, 5))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.figure(figsize=(18, 5))
plt.subplot(1,2,1)
plt.plot(epochs_range, np.log(loss), label='Training Loss')
plt.plot(epochs_range, np.log(val_loss), label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Logarithm of Training and Validation Loss')

plt.subplot(1,2,2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

plt.show()
