# %%
from tensorflow import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D
from keras.activations import leaky_relu 
from keras.preprocessing.image import ImageDataGenerator
from keras import Sequential
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
model = Sequential()

model.add(Conv2D(198, (3,3), input_shape=(227,227,1)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(357, (3,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(50))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 225, 225, 198)     1980
#
#  max_pooling2d_2 (MaxPooling  (None, 112, 112, 198)    0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 110, 110, 357)     636531
#
#  max_pooling2d_3 (MaxPooling  (None, 55, 55, 357)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1079925)           0
#
#  dense_2 (Dense)             (None, 50)                53996300
#
#  activation_2 (Activation)   (None, 50)                0
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense_3 (Dense)             (None, 1)                 51
#
#  activation_3 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 54,634,862
# Trainable params: 54,634,862
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_dir="/notebooks/thermograms/Desenvolvimento da Metodologia"
validation_dir=train_dir
batch_size=16
test_train_split=0.2
train_data = image_dataset_from_directory(\
      train_dir,color_mode="grayscale",image_size=(227,227) ,\
      subset='training',seed=12, validation_split=test_train_split,\
      batch_size=batch_size)
validation_data = image_dataset_from_directory(validation_dir,
      color_mode="grayscale",image_size=(227,227), subset='validation',seed=12,\
      validation_split=test_train_split,batch_size=batch_size)
# Out:
# Found 1282 files belonging to 2 classes.
# Using 1026 files for training.
# Found 1282 files belonging to 2 classes.
# Using 256 files for validation.

# %%
model.compile(loss="BinaryCrossentropy", optimizer='Adam', metrics=["BinaryAccuracy"])

# %%
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

# %%
history = model.fit(train_data,
            epochs=100,
            validation_data=validation_data)#,callbacks=[callback])
# Out:
# Epoch 1/100
# 65/65 [==============================] - 6s 79ms/step - loss: 436.3128 - binary_accuracy: 0.6647 - val_loss: 0.7524 - val_binary_accuracy: 0.6172
# Epoch 2/100
# 65/65 [==============================] - 5s 79ms/step - loss: 0.9236 - binary_accuracy: 0.6023 - val_loss: 0.5140 - val_binary_accuracy: 0.6250
# Epoch 3/100
# 65/65 [==============================] - 5s 78ms/step - loss: 0.5732 - binary_accuracy: 0.6033 - val_loss: 3.7654 - val_binary_accuracy: 0.6328
# Epoch 4/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.9559 - binary_accuracy: 0.6072 - val_loss: 0.6539 - val_binary_accuracy: 0.6680
# Epoch 5/100
# 65/65 [==============================] - 5s 79ms/step - loss: 0.5856 - binary_accuracy: 0.6023 - val_loss: 0.5403 - val_binary_accuracy: 0.5938
# Epoch 6/100
# 65/65 [==============================] - 5s 79ms/step - loss: 0.7575 - binary_accuracy: 0.5634 - val_loss: 0.5501 - val_binary_accuracy: 0.5820
# Epoch 7/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6704 - binary_accuracy: 0.5809 - val_loss: 0.4992 - val_binary_accuracy: 0.6172
# Epoch 8/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.9395 - binary_accuracy: 0.6023 - val_loss: 0.6821 - val_binary_accuracy: 0.6797
# Epoch 9/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.7321 - binary_accuracy: 0.6131 - val_loss: 0.5790 - val_binary_accuracy: 0.5977
# Epoch 10/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6211 - binary_accuracy: 0.5819 - val_loss: 0.5906 - val_binary_accuracy: 0.5977
# Epoch 11/100
# 65/65 [==============================] - 5s 81ms/step - loss: 0.6254 - binary_accuracy: 0.5731 - val_loss: 0.5906 - val_binary_accuracy: 0.5977
# Epoch 12/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6248 - binary_accuracy: 0.5809 - val_loss: 0.5906 - val_binary_accuracy: 0.5977
# Epoch 13/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6146 - binary_accuracy: 0.5867 - val_loss: 0.5792 - val_binary_accuracy: 0.6133
# Epoch 14/100
# 65/65 [==============================] - 5s 79ms/step - loss: 0.6190 - binary_accuracy: 0.5867 - val_loss: 0.5792 - val_binary_accuracy: 0.6133
# Epoch 15/100
# 65/65 [==============================] - 5s 79ms/step - loss: 0.6191 - binary_accuracy: 0.5838 - val_loss: 0.5791 - val_binary_accuracy: 0.6133
# Epoch 16/100
# 65/65 [==============================] - 5s 80ms/step - loss: 1.3147 - binary_accuracy: 0.5945 - val_loss: 0.7640 - val_binary_accuracy: 0.7031
# Epoch 17/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.9513 - binary_accuracy: 0.5595 - val_loss: 0.6064 - val_binary_accuracy: 0.5586
# Epoch 18/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6396 - binary_accuracy: 0.5556 - val_loss: 0.9550 - val_binary_accuracy: 0.6523
# Epoch 19/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6695 - binary_accuracy: 0.6043 - val_loss: 1.0737 - val_binary_accuracy: 0.5898
# Epoch 20/100
# 65/65 [==============================] - 5s 81ms/step - loss: 1.6874 - binary_accuracy: 0.6101 - val_loss: 1.3417 - val_binary_accuracy: 0.6797
# Epoch 21/100
# 65/65 [==============================] - 5s 81ms/step - loss: 0.7625 - binary_accuracy: 0.5936 - val_loss: 0.6453 - val_binary_accuracy: 0.5625
# Epoch 22/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6620 - binary_accuracy: 0.5439 - val_loss: 0.6621 - val_binary_accuracy: 0.5469
# Epoch 23/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6612 - binary_accuracy: 0.5448 - val_loss: 0.6621 - val_binary_accuracy: 0.5469
# Epoch 24/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6619 - binary_accuracy: 0.5439 - val_loss: 0.6621 - val_binary_accuracy: 0.5469
# Epoch 25/100
# 65/65 [==============================] - 5s 80ms/step - loss: 1.3304 - binary_accuracy: 0.5507 - val_loss: 0.9501 - val_binary_accuracy: 0.5898
# Epoch 26/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6443 - binary_accuracy: 0.5663 - val_loss: 1.0601 - val_binary_accuracy: 0.5898
# Epoch 27/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6438 - binary_accuracy: 0.5653 - val_loss: 1.0608 - val_binary_accuracy: 0.5898
# Epoch 28/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.9624 - binary_accuracy: 0.5526 - val_loss: 0.6679 - val_binary_accuracy: 0.5391
# Epoch 29/100
# 65/65 [==============================] - 5s 81ms/step - loss: 0.6634 - binary_accuracy: 0.5409 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 30/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6648 - binary_accuracy: 0.5390 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 31/100
# 65/65 [==============================] - 5s 81ms/step - loss: 0.6669 - binary_accuracy: 0.5361 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 32/100
# 65/65 [==============================] - 5s 81ms/step - loss: 0.6625 - binary_accuracy: 0.5429 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 33/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6619 - binary_accuracy: 0.5429 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 34/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6625 - binary_accuracy: 0.5429 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 35/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6640 - binary_accuracy: 0.5409 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 36/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6647 - binary_accuracy: 0.5400 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 37/100
# 65/65 [==============================] - 5s 81ms/step - loss: 0.6640 - binary_accuracy: 0.5400 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 38/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6648 - binary_accuracy: 0.5390 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 39/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6633 - binary_accuracy: 0.5419 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 40/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6625 - binary_accuracy: 0.5429 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 41/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6647 - binary_accuracy: 0.5400 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 42/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6632 - binary_accuracy: 0.5419 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 43/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6612 - binary_accuracy: 0.5439 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 44/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6626 - binary_accuracy: 0.5419 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 45/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6640 - binary_accuracy: 0.5400 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 46/100
# 65/65 [==============================] - 5s 82ms/step - loss: 0.6655 - binary_accuracy: 0.5380 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 47/100
# 65/65 [==============================] - 5s 81ms/step - loss: 0.6655 - binary_accuracy: 0.5380 - val_loss: 0.6650 - val_binary_accuracy: 0.5430
# Epoch 48/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6633 - binary_accuracy: 0.5409 - val_loss: 0.6650 - val_binary_accuracy: 0.5430
# Epoch 49/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6619 - binary_accuracy: 0.5429 - val_loss: 0.6650 - val_binary_accuracy: 0.5430
# Epoch 50/100
# 65/65 [==============================] - 5s 79ms/step - loss: 0.6618 - binary_accuracy: 0.5439 - val_loss: 0.6650 - val_binary_accuracy: 0.5430
# Epoch 51/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6646 - binary_accuracy: 0.5400 - val_loss: 0.6650 - val_binary_accuracy: 0.5430
# Epoch 52/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6632 - binary_accuracy: 0.5419 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 53/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6618 - binary_accuracy: 0.5439 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 54/100
# 65/65 [==============================] - 5s 83ms/step - loss: 0.6626 - binary_accuracy: 0.5419 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 55/100
# 65/65 [==============================] - 5s 81ms/step - loss: 0.6625 - binary_accuracy: 0.5429 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 56/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6619 - binary_accuracy: 0.5429 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 57/100
# 65/65 [==============================] - 5s 81ms/step - loss: 0.6640 - binary_accuracy: 0.5400 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 58/100
# 65/65 [==============================] - 5s 81ms/step - loss: 0.6633 - binary_accuracy: 0.5409 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 59/100
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6646 - binary_accuracy: 0.5400 - val_loss: 0.6649 - val_binary_accuracy: 0.5430
# Epoch 60/100
# 63/65 [============================>.] - ETA: 0s - loss: 0.6649 - binary_accuracy: 0.5387
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 history = model.fit(train_data,
#       2             epochs=100,
#       3             validation_data=validation_data)#,callbacks=[callback])
#
# File /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.9/dist-packages/keras/engine/training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
epochs_run=len(history.epoch)

# %%
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs_run)
plt.style.use('ggplot')
plt.figure(figsize=(18, 5))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.figure(figsize=(18, 5))
plt.subplot(1,2,1)
plt.plot(epochs_range, np.log(loss), label='Training Loss')
plt.plot(epochs_range, np.log(val_loss), label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Logarithm of Training and Validation Loss')

plt.subplot(1,2,2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

plt.show()
