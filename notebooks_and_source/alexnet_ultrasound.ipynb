# %%
from tensorflow import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D
from keras.activations import leaky_relu 
from keras.preprocessing.image import ImageDataGenerator         
from keras import Sequential
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
np.random.seed(888)

#Instantiate an empty model
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(227, 227,1), kernel_size=(11,11), strides=(4,4), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# Passing it to a Fully Connected layer
model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(4096)) #input_shape=(225*225,)))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))

# 2nd Fully Connected Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# 3rd Fully Connected Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# Output Layer
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 57, 57, 96)        11712
#
#  activation (Activation)     (None, 57, 57, 96)        0
#
#  max_pooling2d (MaxPooling2D  (None, 29, 29, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 256)       614656
#
#  activation_1 (Activation)   (None, 29, 29, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 384)       885120
#
#  activation_2 (Activation)   (None, 15, 15, 384)       0
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 384)       1327488
#
#  activation_3 (Activation)   (None, 15, 15, 384)       0
#
#  conv2d_4 (Conv2D)           (None, 15, 15, 256)       884992
#
#  activation_4 (Activation)   (None, 15, 15, 256)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 4096)              67112960
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 1000)              4097000
#
#  activation_7 (Activation)   (None, 1000)              0
#
#  dropout_2 (Dropout)         (None, 1000)              0
#
#  dense_3 (Dense)             (None, 1)                 1001
#
#  activation_8 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 91,716,241
# Trainable params: 91,716,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
image_shape=(227,227)
train_dir="/notebooks/ultrasound/train"
validation_dir=train_dir
test_dir="/notebooks/ultrasound/val"
batch_size=64
test_train_split=0.3

train_data = image_dataset_from_directory(\
      train_dir,color_mode="grayscale",image_size=image_shape ,\
      subset='training',seed=5, validation_split=test_train_split,\
      batch_size=batch_size)
validation_data = image_dataset_from_directory(validation_dir,
      color_mode="grayscale",image_size=image_shape, subset='validation',seed=5,\
      validation_split=test_train_split,batch_size=batch_size)
test_data = image_dataset_from_directory(test_dir,
      color_mode="grayscale",image_size=image_shape, batch_size=batch_size)
# Out:
# Found 8116 files belonging to 2 classes.
# Using 5682 files for training.
# Found 8116 files belonging to 2 classes.
# Using 2434 files for validation.
# Found 900 files belonging to 2 classes.

# %%
model.compile(loss="BinaryCrossentropy", optimizer='Adam', metrics=["BinaryAccuracy"])

# %%
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# %%
history = model.fit(train_data,
            epochs=100,
            validation_data=validation_data,callbacks=[callback])
# Out:
# Epoch 1/100
# 89/89 [==============================] - 13s 115ms/step - loss: 22.0490 - binary_accuracy: 0.5625 - val_loss: 0.6845 - val_binary_accuracy: 0.5592
# Epoch 2/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.6349 - binary_accuracy: 0.6508 - val_loss: 0.5242 - val_binary_accuracy: 0.7469
# Epoch 3/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.6136 - binary_accuracy: 0.6631 - val_loss: 0.5017 - val_binary_accuracy: 0.7539
# Epoch 4/100
# 89/89 [==============================] - 9s 94ms/step - loss: 0.5128 - binary_accuracy: 0.7425 - val_loss: 0.4484 - val_binary_accuracy: 0.7613
# Epoch 5/100
# 89/89 [==============================] - 9s 95ms/step - loss: 0.4134 - binary_accuracy: 0.8008 - val_loss: 0.3503 - val_binary_accuracy: 0.8373
# Epoch 6/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.3424 - binary_accuracy: 0.8418 - val_loss: 0.2744 - val_binary_accuracy: 0.8763
# Epoch 7/100
# 89/89 [==============================] - 8s 93ms/step - loss: 0.3135 - binary_accuracy: 0.8567 - val_loss: 0.3340 - val_binary_accuracy: 0.8525
# Epoch 8/100
# 89/89 [==============================] - 8s 93ms/step - loss: 0.2653 - binary_accuracy: 0.8816 - val_loss: 0.2111 - val_binary_accuracy: 0.9047
# Epoch 9/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.2087 - binary_accuracy: 0.9113 - val_loss: 0.2365 - val_binary_accuracy: 0.8961
# Epoch 10/100
# 89/89 [==============================] - 9s 95ms/step - loss: 0.1932 - binary_accuracy: 0.9201 - val_loss: 0.1929 - val_binary_accuracy: 0.9269
# Epoch 11/100
# 89/89 [==============================] - 9s 94ms/step - loss: 0.1566 - binary_accuracy: 0.9338 - val_loss: 0.1321 - val_binary_accuracy: 0.9478
# Epoch 12/100
# 89/89 [==============================] - 10s 111ms/step - loss: 0.1362 - binary_accuracy: 0.9440 - val_loss: 0.1340 - val_binary_accuracy: 0.9495
# Epoch 13/100
# 89/89 [==============================] - 9s 97ms/step - loss: 0.1573 - binary_accuracy: 0.9379 - val_loss: 0.1257 - val_binary_accuracy: 0.9503
# Epoch 14/100
# 89/89 [==============================] - 9s 95ms/step - loss: 0.1019 - binary_accuracy: 0.9600 - val_loss: 0.1342 - val_binary_accuracy: 0.9523
# Epoch 15/100
# 89/89 [==============================] - 9s 97ms/step - loss: 0.0962 - binary_accuracy: 0.9623 - val_loss: 0.1079 - val_binary_accuracy: 0.9532
# Epoch 16/100
# 89/89 [==============================] - 9s 95ms/step - loss: 0.0894 - binary_accuracy: 0.9652 - val_loss: 0.1234 - val_binary_accuracy: 0.9569
# Epoch 17/100
# 89/89 [==============================] - 9s 94ms/step - loss: 0.0728 - binary_accuracy: 0.9743 - val_loss: 0.1042 - val_binary_accuracy: 0.9622
# Epoch 18/100
# 89/89 [==============================] - 9s 95ms/step - loss: 0.0652 - binary_accuracy: 0.9754 - val_loss: 0.0876 - val_binary_accuracy: 0.9741
# Epoch 19/100
# 89/89 [==============================] - 9s 94ms/step - loss: 0.0538 - binary_accuracy: 0.9805 - val_loss: 0.0689 - val_binary_accuracy: 0.9753
# Epoch 20/100
# 89/89 [==============================] - 9s 94ms/step - loss: 0.0906 - binary_accuracy: 0.9692 - val_loss: 0.1001 - val_binary_accuracy: 0.9659
# Epoch 21/100
# 89/89 [==============================] - 9s 95ms/step - loss: 0.1455 - binary_accuracy: 0.9539 - val_loss: 0.0715 - val_binary_accuracy: 0.9717
# Epoch 22/100
# 89/89 [==============================] - 10s 109ms/step - loss: 0.0453 - binary_accuracy: 0.9812 - val_loss: 0.0652 - val_binary_accuracy: 0.9774
# Epoch 23/100
# 89/89 [==============================] - 9s 94ms/step - loss: 0.0679 - binary_accuracy: 0.9764 - val_loss: 0.1247 - val_binary_accuracy: 0.9597
# Epoch 24/100
# 89/89 [==============================] - 9s 97ms/step - loss: 0.0703 - binary_accuracy: 0.9738 - val_loss: 0.0740 - val_binary_accuracy: 0.9758
# Epoch 25/100
# 89/89 [==============================] - 9s 95ms/step - loss: 0.0432 - binary_accuracy: 0.9845 - val_loss: 0.0663 - val_binary_accuracy: 0.9782

# %%
epochs_run=len(history.epoch)

# %%
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs_run)
plt.style.use('ggplot')
plt.figure(figsize=(18, 5))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.figure(figsize=(18, 5))
plt.subplot(1,2,1)
plt.plot(epochs_range, np.log(loss), label='Training Loss')
plt.plot(epochs_range, np.log(val_loss), label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Logarithm of Training and Validation Loss')

plt.subplot(1,2,2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

plt.show()

# %%
results = model.evaluate(test_data)
print("test loss, test acc:", results)
# Out:
# 15/15 [==============================] - 1s 34ms/step - loss: 2.7467 - binary_accuracy: 0.7822
# test loss, test acc: [2.7466986179351807, 0.7822222113609314]
